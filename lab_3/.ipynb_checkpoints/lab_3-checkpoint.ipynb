# %% [markdown]
# <h2>Лабораторна робота №3 ФБ-33 Лозенко Павло</h2>
# <h2>Наука про дані: обмін результатами та початковий аналіз</h2>
#
# Мета роботи: ознайомитися з системою контролю версій GitHub, навчитися
# створювати прості веб-додатки для обміну результатами досліджень із
# використанням модуля spyre.<br>
#
# Хід виконання роботи :

# %% [markdown]
# Створення веб-додатоку із використанням модуля Streamlit:
# 1. Створіть dropdown список, який дозволить обрати часовий ряд VCI, TCI, VHI для
# набору даних із лабораторної роботи 2;
# 2. Створіть dropdown список, який дозволить вибрати область, для якої буде
# виконуватись аналіз;
# 3. Створіть slider, який дозволить зазначити інтервал тижнів, за які відбираються дані;
# 4. Створіть slider, який дозволить зазначити інтервал років, за які відбираються дані;
# 5. Створіть button для скидання всіх фільтрів і повернення до початкового стану даних
# (відповідно інтерактивні елементи повинні мати початкові значення);
# 6. Створіть три вкладки для відображення таблиці з відфільтрованими даними,
# відповідного до неї графіка та графіка порівняння даних по областях.
# 7. Перший графік повинен відображати відфільтровані дані (часові ряди за діапазон
# років, що обмежені інтервалом тижнів). Другий графік має відображати порівняння
# значень VCI, TCI або VHI (залежно від обраної опції у списку dropdown) для обраної
# області з усіма іншими областями за вказаний часовий інтервал. Продумайте
# вигляд цих графіків.
# 8. Створіть два checkbox для сортування даних за зростанням та спаданням значень
# VCI, TCI або VHI (залежно від обраної опції у списку dropdown). Продумайте реакцію
# програми, якщо увімкнені обидва чекбокси.
# 9. Інтерактивні елементи мають бути розміщений в одній колонці, а графіки з
# таблицею — в іншій.
# Робота з GitHub:
# 1. Зареєструйтесь на GitHub;
# 2. Створіть public репозиторій;
# 3. Додайте другу та третю лабораторні роботи в цей репозиторій. Кожна лабораторна
# повинна бути в окремій директорії;
# 4. Репозиторій повинен мати заповнений файл README.MD та .gitignore, в якому
# прописані винятки для Git: таблиці та інші дані, що використовуються.

# %%
import os
import streamlit as st
import pandas as pd
import matplotlib
matplotlib.use('Agg')  
import matplotlib.pyplot as plt
import seaborn as sns
import tempfile
from download_csv import download_csv
from data_cleaning import read_data
from replace import replace_function


country = "UKR"
year_1 = 1982
year_2 = 2025
type_data = "Mean"
directory = os.path.join(os.getcwd(), "data_csv")

PROVINCE_NAME_dict = {
    1: 'Вінницька', 2: 'Волинська', 3: 'Дніпропетровська', 4: 'Донецька', 5: 'Житомирська',
    6: 'Закарпатська', 7: 'Запорізька', 8: 'Івано-Франківська', 9: 'Київська', 10: 'Кіровоградська',
    11: 'Луганська', 12: 'Львівська', 13: 'Миколаївська', 14: 'Одеська', 15: 'Полтавська',
    16: 'Рівенська', 17: 'Сумська', 18: 'Тернопільська', 19: 'Харківська', 20: 'Херсонська',
    21: 'Хмельницька', 22: 'Черкаська', 23: 'Чернівецька', 24: 'Чернігівська', 25: 'Республіка Крим'
}


@st.cache_data
def load_data():
    download_csv(country, year_1, year_2, type_data, directory)
    data_frames = read_data(directory)
    if data_frames is None:
        st.error("No valid data loaded from the directory. Please check the CSV files or download fresh data.")
        st.stop()
    return replace_function(data_frames)

# Load data
data_frames_work = load_data()


st.title("NOAA Data Visualization")


show_debug = st.checkbox("Show Debug Information", value=False)

if show_debug:
    st.write(f"Loaded data_frames_work with {len(data_frames_work)} rows and columns: {list(data_frames_work.columns)}")
    st.write(f"Available PROVINCE_ID values: {sorted(data_frames_work['PROVINCE_ID'].unique())}")


index = st.selectbox("NOAA Data Type", options=['VCI', 'TCI', 'VHI'], 
                     format_func=lambda x: {'VCI': 'Vegetation Condition Index (VCI)', 
                                           'TCI': 'Temperature Condition Index (TCI)', 
                                           'VHI': 'Vegetation Health (VHI)'}[x])
region = st.selectbox("Region", options=sorted(data_frames_work['PROVINCE_ID'].unique()), 
                      format_func=lambda x: PROVINCE_NAME_dict.get(x, str(x)), index=1)  # Default to Волинська
range_weeks = st.text_input("Range of Weeks (1 - 52)", value="1 - 52")
range_year = st.text_input("Range of Years", value="1982 - 2024")


if 'data_frame' not in st.session_state:
    st.session_state.data_frame = None

def filter_data(index, region, range_weeks, range_year):
    try:
        week_1, week_2 = map(int, range_weeks.strip().split('-'))
        year_1, year_2 = map(int, range_year.strip().split('-'))
        
        if not (1 <= week_1 <= week_2 <= 52):
            st.error("Week range must be between 1 and 52.")
            return None
        if not (1982 <= year_1 <= year_2 <= 2024):
            st.error("Year range must be between 1982 and 2024.")
            return None

        province_name = PROVINCE_NAME_dict.get(int(region), "")
        data_frame = data_frames_work[
            (data_frames_work["PROVINCE_ID"] == int(region)) &
            (data_frames_work["Week"].between(week_1, week_2)) &
            (data_frames_work["Year"].between(year_1, year_2))
        ][["PROVINCE_ID", "Year", "Week", index]]
        data_frame.insert(0, "PROVINCE_NAME", province_name)

        if show_debug:
            st.write(f"Filtered data with {len(data_frame)} rows for {province_name}, "
                      f"weeks {week_1}-{week_2}, years {year_1}-{year_2}, index {index}")
            if not data_frame.empty:
                st.write(f"Sample data: {data_frame.head().to_dict()}")
        
        return data_frame
    except Exception as e:
        st.error(f"Error: {e}. Use format like '1 - 52' for weeks and years.")
        return None


if st.button("Get Data"):
    st.session_state.data_frame = filter_data(index, region, range_weeks, range_year)


if st.session_state.data_frame is None:
    st.session_state.data_frame = filter_data(index, region, range_weeks, range_year)


tab1, tab2 = st.tabs(["Data Table", "Visualizations"])

with tab1:
    if st.session_state.data_frame is None or st.session_state.data_frame.empty:
        st.warning(f"No data available for {PROVINCE_NAME_dict.get(int(region), region)}, "
                   f"weeks {range_weeks}, years {range_year}, index {index}. Try different parameters.")
    else:
        st.subheader("Data Table")
        st.dataframe(st.session_state.data_frame)

with tab2:
    if st.session_state.data_frame is None or st.session_state.data_frame.empty:
        st.warning(f"No data to plot for {PROVINCE_NAME_dict.get(int(region), region)}, "
                   f"weeks {range_weeks}, years {range_year}, index {index}. Try different parameters.")
    else:
        st.subheader("Data Visualization")
        df = st.session_state.data_frame.drop(['PROVINCE_ID'], axis=1)


        fig1, ax1 = plt.subplots(figsize=(10, 7))
        sns.lineplot(x='Week', y=index, hue='Year', data=df, marker='o', ax=ax1, linestyle='-')
        ax1.set_title(f"{index} for {country}: {df.iloc[0]['PROVINCE_NAME']}", 
                      fontsize=14, weight='bold')
        ax1.set_xlabel("Week", fontsize=12, weight='bold')
        ax1.set_ylabel(index, fontsize=12, weight='bold')
        ax1.grid(True, linestyle='--', alpha=0.95)
        ax1.legend(title="Year", fontsize=10, title_fontsize=12)
        ax1.tick_params(axis='both', labelsize=10)
        ax1.set_xlim(df['Week'].min() - 1, df['Week'].max() + 1)
        ax1.set_ylim(df[index].min() * 0.9, df[index].max() * 1.1)
        with tempfile.NamedTemporaryFile(delete=False, suffix=".png") as tmpfile:
            fig1.savefig(tmpfile.name)
            st.image(tmpfile.name)
        os.unlink(tmpfile.name)
        plt.close(fig1)


        fig2, ax2 = plt.subplots(figsize=(10, 7))
        pivot_data = df.pivot(index="Week", columns="Year", values=index)
        sns.heatmap(pivot_data, cmap="Greens", annot=True, fmt=".1f", ax=ax2)
        ax2.set_title(f"{index} for {country}: {df.iloc[0]['PROVINCE_NAME']}", 
                      fontsize=14, weight='bold')
        with tempfile.NamedTemporaryFile(delete=False, suffix=".png") as tmpfile:
            fig2.savefig(tmpfile.name)
            st.image(tmpfile.name)
        os.unlink(tmpfile.name)
        plt.close(fig2)
# Out:
# 2025-06-03 13:50:53.622 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-06-03 13:50:53.624 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-06-03 13:50:53.625 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:50:54.301
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run Y:\labs\venv_spyre\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-06-03 13:50:54.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:50:54.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:50:54.814 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:50:54.816 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Do you want to clean the directory and download fresh data? (y/n):  n
# [+] Directory cleaning skipped: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv
#
# Using existing data in the directory.
# [+] Reading CSV files from directory: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_10_2025-05-29_16-06-00.csv
# [+] Added DataFrame for province_ID 10 from file: NOAA_ID_10_2025-05-29_16-06-00.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_11_2025-05-29_16-06-01.csv
# [+] Added DataFrame for province_ID 11 from file: NOAA_ID_11_2025-05-29_16-06-01.csv
# [-] Skipping excluded province_ID 12 for file: NOAA_ID_12_2025-05-29_16-06-02.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_13_2025-05-29_16-06-03.csv
# [+] Added DataFrame for province_ID 13 from file: NOAA_ID_13_2025-05-29_16-06-03.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_14_2025-05-29_16-06-04.csv
# [+] Added DataFrame for province_ID 14 from file: NOAA_ID_14_2025-05-29_16-06-04.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_15_2025-05-29_16-06-05.csv
# [+] Added DataFrame for province_ID 15 from file: NOAA_ID_15_2025-05-29_16-06-05.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_16_2025-05-29_16-06-06.csv
# [+] Added DataFrame for province_ID 16 from file: NOAA_ID_16_2025-05-29_16-06-06.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_17_2025-05-29_16-06-07.csv
# [+] Added DataFrame for province_ID 17 from file: NOAA_ID_17_2025-05-29_16-06-07.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_18_2025-05-29_16-06-08.csv
# [+] Added DataFrame for province_ID 18 from file: NOAA_ID_18_2025-05-29_16-06-08.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_19_2025-05-29_16-06-09.csv
# [+] Added DataFrame for province_ID 19 from file: NOAA_ID_19_2025-05-29_16-06-09.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_1_2025-05-29_16-05-51.csv
# [+] Added DataFrame for province_ID 1 from file: NOAA_ID_1_2025-05-29_16-05-51.csv
# [-] Skipping excluded province_ID 20 for file: NOAA_ID_20_2025-05-29_16-06-10.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_21_2025-05-29_16-06-11.csv
# [+] Added DataFrame for province_ID 21 from file: NOAA_ID_21_2025-05-29_16-06-11.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_22_2025-05-29_16-06-12.csv
# [+] Added DataFrame for province_ID 22 from file: NOAA_ID_22_2025-05-29_16-06-12.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_23_2025-05-29_16-06-12.csv
# [+] Added DataFrame for province_ID 23 from file: NOAA_ID_23_2025-05-29_16-06-12.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_24_2025-05-29_16-06-13.csv
# [+] Added DataFrame for province_ID 24 from file: NOAA_ID_24_2025-05-29_16-06-13.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_25_2025-05-29_16-06-14.csv
# [+] Added DataFrame for province_ID 25 from file: NOAA_ID_25_2025-05-29_16-06-14.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_26_2025-05-29_16-06-15.csv
# [+] Added DataFrame for province_ID 26 from file: NOAA_ID_26_2025-05-29_16-06-15.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_27_2025-05-29_16-06-17.csv
# [+] Added DataFrame for province_ID 27 from file: NOAA_ID_27_2025-05-29_16-06-17.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_2_2025-05-29_16-05-52.csv
# [+] Added DataFrame for province_ID 2 from file: NOAA_ID_2_2025-05-29_16-05-52.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_3_2025-05-29_16-05-53.csv
# [+] Added DataFrame for province_ID 3 from file: NOAA_ID_3_2025-05-29_16-05-53.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_4_2025-05-29_16-05-54.csv
# [+] Added DataFrame for province_ID 4 from file: NOAA_ID_4_2025-05-29_16-05-54.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_5_2025-05-29_16-05-55.csv
# [+] Added DataFrame for province_ID 5 from file: NOAA_ID_5_2025-05-29_16-05-55.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_6_2025-05-29_16-05-56.csv
# [+] Added DataFrame for province_ID 6 from file: NOAA_ID_6_2025-05-29_16-05-56.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_7_2025-05-29_16-05-57.csv
# [+] Added DataFrame for province_ID 7 from file: NOAA_ID_7_2025-05-29_16-05-57.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_8_2025-05-29_16-05-58.csv
# [+] Added DataFrame for province_ID 8 from file: NOAA_ID_8_2025-05-29_16-05-58.csv
# [+] Successfully processed file: C:\Users\pavlo\OneDrive\Рабочий стол\Зад\git\Data_Analysis\lab_3\data_csv\NOAA_ID_9_2025-05-29_16-05-58.csv
# [+] Added DataFrame for province_ID 9 from file: NOAA_ID_9_2025-05-29_16-05-58.csv
# [+] Concatenating 25 DataFrames
# 2025-06-03 13:51:01.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.664 Session state does not function when running a script without `streamlit run`
# 2025-06-03 13:51:01.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:01.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:02.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:02.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:02.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:04.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:04.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-03 13:51:04.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
